# %% [markdown]
# # nano-vLLM Colab A100 Benchmark Bootstrap
#
# Run the next cell in a Colab A100 runtime. It mounts Google Drive, clones the PR branch, and writes all outputs under `MyDrive/nano-vllm-colab-a100/2026-06-16/`.

# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=False)
# !rm -rf /content/nano-vllm-online-serving
# !git clone --branch codex/colab-a100-runner-pr https://github.com/shunwendongan/nano-vllm-online-serving.git /content/nano-vllm-online-serving
# %cd /content/nano-vllm-online-serving
# !python scripts/run_colab_a100_experiment.py --output-root /content/drive/MyDrive/nano-vllm-colab-a100/2026-06-16
